# %%
### FINAL PROJECT ###

# The main function #

######Set up and check GPU########
import tensorflow as tf
# device_name = tf.test.gpu_device_name()
# if device_name != '/device:GPU:0':
#   raise SystemError('GPU device not found')
# print('Found GPU at: {}'.format(device_name))


####Set Up Keras######
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils import plot_model
# import graphviz
import numpy
import pandas as pd

# set the seed for reproducibility
#numpy.random.seed(7)

#######Load Data as DF#######  
# dataset = numpy.loadtxt("poker_data_clean.csv", delimiter=",",skiprows=1)
dataset = pd.read_csv("poker_data_clean_2.csv")
dataset = dataset.sample(frac=1).reset_index(drop=True)
# SHUFFLE the rows
# list(dataset)
# dataset

# %%
# dataset

# %%
# from main import *
import io

# Create training set
# split into input (X) and output (Y) variables
X = dataset.iloc[0:80000,7:73]
Y = dataset.iloc[0:80000,73:79]
# Create test set
Xtest = dataset.iloc[80000:90000,7:73]
Ytest = dataset.iloc[80000:90000,73:79]


"""# Section 1: Set up the Model"""
for i in range(1):
    
    # First create Model for all of our data
    model = Sequential()
    #model.add(Dense(100,input_dim=66, activation='relu'))
    #model.add(Dropout(0.5))
    #model.add(Dense(i, input_dim=66, activation='relu'))
    #model.add(Dropout(0.50))
    model.add(Dense(48,input_dim = 66,activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(20, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(6,activation='softmax'))
    # Compile model
    adam = keras.optimizers.Adam(lr=0.020, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.00001, amsgrad=False)
    model.compile(loss='categorical_crossentropy', optimizer= adam, metrics=['categorical_accuracy'])

    # Fit the model
    model.fit(X, Y, epochs= 250, batch_size=32)

    # b = model.predict_classes(x= X, batch_size= 32)
    #  1 Hidden Layer -> 87.56% acc 66 -> 15 -> 6 for 250 epochs
    #  1 Hidden Layers -> 88.10% acc 66 -> 30 -> 6 for 150 epochs
    # evaluate the model
    scores = model.evaluate(Xtest, Ytest)
    print("\n%.0f : %s: %.2f%%" % (i,model.metrics_names[1], scores[1]*100))
# Out:
# Epoch 1/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.4858 - categorical_accuracy: 0.8387
# Epoch 2/250
# 80000/80000 [==============================] - 5s 67us/step - loss: 0.4107 - categorical_accuracy: 0.8568
# Epoch 3/250
# 80000/80000 [==============================] - 6s 70us/step - loss: 0.3995 - categorical_accuracy: 0.8571
# Epoch 4/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.3922 - categorical_accuracy: 0.8611
# Epoch 5/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.3824 - categorical_accuracy: 0.8623
# Epoch 6/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.3777 - categorical_accuracy: 0.8666
# Epoch 7/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.3730 - categorical_accuracy: 0.8669
# Epoch 8/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.3652 - categorical_accuracy: 0.8684
# Epoch 9/250
# 80000/80000 [==============================] - 6s 78us/step - loss: 0.3608 - categorical_accuracy: 0.8706
# Epoch 10/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.3618 - categorical_accuracy: 0.8697
# Epoch 11/250
# 80000/80000 [==============================] - 6s 78us/step - loss: 0.3588 - categorical_accuracy: 0.8719
# Epoch 12/250
# 80000/80000 [==============================] - 6s 80us/step - loss: 0.3514 - categorical_accuracy: 0.8721
# Epoch 13/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.3506 - categorical_accuracy: 0.8728
# Epoch 14/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.3503 - categorical_accuracy: 0.8722
# Epoch 15/250
# 80000/80000 [==============================] - 6s 76us/step - loss: 0.3483 - categorical_accuracy: 0.8731
# Epoch 16/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.3414 - categorical_accuracy: 0.8746
# Epoch 17/250
# 80000/80000 [==============================] - 6s 78us/step - loss: 0.3421 - categorical_accuracy: 0.8748
# Epoch 18/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0
250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.2868 - categorical_accuracy: 0.8883
# Epoch 82/250
# 80000/80000 [==============================] - 6s 81us/step - loss: 0.2848 - categorical_accuracy: 0.8886
# Epoch 83/250
# 80000/80000 [==============================] - 6s 78us/step - loss: 0.2843 - categorical_accuracy: 0.8883
# Epoch 84/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.2856 - categorical_accuracy: 0.8876
# Epoch 85/250
# 80000/80000 [==============================] - 6s 74us/step - loss: 0.2833 - categorical_accuracy: 0.8875
# Epoch 86/250
# 80000/80000 [==============================] - 6s 80us/step - loss: 0.2860 - categorical_accuracy: 0.8873
# Epoch 87/250
# 80000/80000 [==============================] - 6s 79us/step - loss: 0.2844 - categorical_accuracy: 0.8887
# Epoch 88/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.2834 - categorical_accuracy: 0.8891
# Epoch 89/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.2856 - categorical_accuracy: 0.8886
# Epoch 90/250
# 80000/80000 [==============================] - 6s 74us/step - loss: 0.2822 - categorical_accuracy: 0.8885
# Epoch 91/250
# 80000/80000 [==============================] - 6s 75us/step - loss: 0.2848 - categorical_accuracy: 0.8879
# Epoch 92/250
# 80000/80000 [==============================] - 6s 80us/step - loss: 0.2863 - categorical_accuracy: 0.8885
# Epoch 93/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.2836 - categorical_accuracy: 0.8879
# Epoch 94/250
# 80000/80000 [==============================] - 6s 80us/step - loss: 0.2786 - categorical_accuracy: 0.8887
# Epoch 95/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.2825 - categorical_accuracy: 0.8887
# Epoch 96/250
# 80000/80000 [==============================] - 6s 78us/step - loss: 0.2807 - categorical_accuracy: 0.8893
# Epoch 97/250
# 80000/80000 [==============================] - 6s 74us/step - loss: 0.2819 - categorical_accuracy: 0.8882
# Epoch 98/250
# 80000/80000 [==============================] - 6s 77us/step - loss: 0.2819 - categorical_accuracy: 0.8891
# Epoch 99/250
# 80000/80000 [==============================] - 7s 82us/step - loss: 0.2806 - categorical_accuracy: 0.8887
# Epoch 100/250
# 80000/80000 [==============================] - 6s 78us/step - loss: 0.2795 - categorical_accuracy: 0.8892
# Epoch 101/250
# 80000/80000 [==============================] - 6s 81us/step - loss: 0.2806 - categorical_accuracy: 0.8885
# Epoch 102/250
# 80000/80000 [==============================] - 6s 80us/step - loss: 0.2798 - categorical_accuracy: 0.8899
# Epoch 103/250
# 80000/80000 [==============================] - 6s 80us/step - loss: 0.2820 - categorical_accuracy: 0.8910
# Epoch 104/250
# 80000/80000 [==============================] - 6s 80us/step - loss: 0.2787 - categorical_accuracy: 0.8884
# Epoch 105/250
# 80000/80000 [==============================] - 6s 79us/step - loss: 0.2790 - categorical_accuracy: 0.8888
# Epoch 106/250
# 33824/80000 [===========>..................] - ETA: 4s - loss: 0.2769 - categorical_accuracy: 0.8897

# %%
#model.fit(X_2,Y_2, epochs =100, batch_size =32)

    # b = model.predict_classes(x= X, batch_size= 32)
    #  1 Hidden Layer -> 87.56% acc 66 -> 15 -> 6 for 250 epochs
    #  1 Hidden Layers -> 88.10% acc 66 -> 30 -> 6 for 150 epochs
    # evaluate the model
#scores = model.evaluate(Xtest, Ytest)
# print("\n%.0f : %s: %.2f%%" % (i,model.metrics_names[1], scores[1]*100))

# %%
model.summary()
#model.layers
#model.get_weights()
# print(b)
# import pydot
# plot_model(model, to_file='model.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-53a96c3fe19e> in <module>()
# ----> 1 model.summary()
#       2 #model.layers
#       3 #model.get_weights()
#       4 # print(b)
#       5 # import pydot
#
# NameError: name 'model' is not defined
